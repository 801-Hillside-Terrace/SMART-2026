# %% [markdown]
# <a href="https://colab.research.google.com/github/801-Hillside-Terrace/SMART-2026/blob/main/week5/week5_spotify_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import csv
import joblib
import os

# load data (already standardized)

if not os.path.exists('SMART-2026'):
    # !git clone https://github.com/801-Hillside-Terrace/SMART-2026.git

# features are: "danceability", "energy", "loudness", "tempo", "valence", "acousticness", "instrumentalness", "liveness", "speechiness"
X_train = np.load('SMART-2026/project/data/spotify_processed/X_train.npy')
X_val = np.load('SMART-2026/project/data/spotify_processed/X_val.npy')

# target is genre (114 classes)
y_train = np.load('SMART-2026/project/data/spotify_processed/y_clf_train.npy')
y_val = np.load('SMART-2026/project/data/spotify_processed/y_clf_val.npy')

# convert to tensors
X_train = torch.from_numpy(X_train).float()
X_val = torch.from_numpy(X_val).float()
y_train = torch.from_numpy(y_train).long()
y_val = torch.from_numpy(y_val).long()
# Out:
# Cloning into 'SMART-2026'...
# remote: Enumerating objects: 199, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 199 (delta 6), reused 4 (delta 4), pack-reused 175 (from 1)
# Receiving objects: 100% (199/199), 13.31 MiB | 30.49 MiB/s, done.
# Resolving deltas: 100% (74/74), done.
