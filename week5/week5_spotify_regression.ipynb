# %% [markdown]
# <a href="https://colab.research.google.com/github/801-Hillside-Terrace/SMART-2026/blob/main/week5/week5_spotify_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import csv
import joblib
import os

# load data (already standardized)

if not os.path.exists('SMART-2026'):
    # !git clone https://github.com/801-Hillside-Terrace/SMART-2026.git

# features are: "danceability", "energy", "loudness", "tempo", "valence", "acousticness", "instrumentalness", "liveness", "speechiness"
X_train = np.load('SMART-2026/project/data/spotify_processed/X_train.npy')
X_val = np.load('SMART-2026/project/data/spotify_processed/X_val.npy')

# target is popularity
y_train = np.load('SMART-2026/project/data/spotify_processed/y_reg_train.npy')
y_val = np.load('SMART-2026/project/data/spotify_processed/y_reg_val.npy')

# convert to tensors
X_train = torch.from_numpy(X_train).float()
X_val = torch.from_numpy(X_val).float()
y_train = torch.from_numpy(y_train).float()
y_val = torch.from_numpy(y_val).float()
