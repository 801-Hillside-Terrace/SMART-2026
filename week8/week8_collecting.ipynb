# %% [markdown]
# <a href="https://colab.research.google.com/github/801-Hillside-Terrace/SMART-2026/blob/main/week8/week8_collecting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Dataset 1:**

# %% [markdown]
# **Test MSE** for each regression model:
#
# 1. Linear Regression:
#
# 2.  Ridge Regression:
#
# 3.  SVR:
#
# 4.  XGB:
#
# 5.  Neural Network:
#
# 6. Baseline (using train mean):

# %%
'''
# code for neural network regressor to get test MSE


# load in test data and convert to tensors
X_test = np.load('SMART-2026/project/data/spotify_processed/X_test.npy')
y_test = np.load('SMART-2026/project/data/spotify_processed/y_reg_test.npy')

X_test = torch.from_numpy(X_test).float()
y_test = torch.from_numpy(y_test).float().view(-1,1)

test_dataset = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, batch_size = 32, shuffle = False)


model.eval()

test_loss = 0.0
test_total = 0

with torch.no_grad():

  for xb, yb in test_loader:

    xb = xb.to(device)
    yb = yb.to(device)

    preds = model(xb)

    loss = criterion(preds, yb)

    test_loss += loss.item() * xb.shape[0]

    test_total += yb.shape[0]

    test_loss /= test_total

print(f'Test Loss: {test_loss:.4f}')
'''

# %% [markdown]
# **Test Accuracy** for each regression model:
#
# 1.  Softmax Regression:
#
# 2.   Softmax Regression w/ L2 Penalty:
#
# 3.  SVC:
#
# 4.  XGB:
#
# 5.  Neural Network:
#
# 6. Baseline (training class mode):

# %%
'''
# code for neural network classifier to get test accuracy

# load in test data and convert to tensors
X_test = np.load('SMART-2026/project/data/spotify_processed/X_test.npy')
y_test = np.load('SMART-2026/project/data/spotify_processed/y_clf_test.npy')

X_test = torch.from_numpy(X_test).float()
y_test = torch.from_numpy(y_test).long()

test_dataset = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, batch_size = 32, shuffle = False)

model.eval()

test_loss = 0.0
test_correct = 0
test_total = 0

with torch.no_grad():

  for xb, yb in test_loader:

    xb = xb.to(device)
    yb = yb.to(device)

    preds = model(xb)

    loss = criterion(preds, yb)

    test_loss += loss.item() * xb.shape[0]

    predicted = preds.argmax(dim=1)

    test_correct += (predicted == yb).sum().item()

    test_total += yb.shape[0]

test_loss /= test_total
test_acc = test_correct / test_total

print(f'Test Accuracy: {test_acc:.4f}')

'''

# %% [markdown]
# **Train and Val Loss** for every model:
#
# 1. Linear Regression:
#
# 2.  Ridge Regression:
#
# 3.  SVR:
#
# 4.  XGB:
#
# 5.  Neural Network:
#
# 6. Baseline (using train mean):
#
# 7.  Softmax Regression:
#
# 8.   Softmax Regression w/ L2 Penalty:
#
# 9.  SVC:
#
# 10.  XGB:
#
# 11.  Neural Network:
#
# 12. Baseline (training class mode):

# %% [markdown]
# **Linear Regression Coefficients** for each feature:
#
# 1. Danceability:
# 2. Energy:
# 3. Loudness:
# 4. Tempo:
# 5. Valence:
# 6. Acousticness:
# 7. Instrumentalness:
# 8. Liveness:
# 9. Speechiness:

# %% [markdown]
# **Softmax Regression Coefficients** for each feature for a specific genre:
#
# 1. Danceability:
# 2. Energy:
# 3. Loudness:
# 4. Tempo:
# 5. Valence:
# 6. Acousticness:
# 7. Instrumentalness:
# 8. Liveness:
# 9. Speechiness:

# %% [markdown]
# **XGBoost Gain Performance** for each feature (regression):
#
# 1. Danceability:
# 2. Energy:
# 3. Loudness:
# 4. Tempo:
# 5. Valence:
# 6. Acousticness:
# 7. Instrumentalness:
# 8. Liveness:
# 9. Speechiness:

# %% [markdown]
# **XGBoost Gain Performance** for each feature (classification):
#
# 1. Danceability:
# 2. Energy:
# 3. Loudness:
# 4. Tempo:
# 5. Valence:
# 6. Acousticness:
# 7. Instrumentalness:
# 8. Liveness:
# 9. Speechiness:

# %% [markdown]
# **Neural Network Permutation Importance** for each feature (regression):
#
# 1. Danceability:
# 2. Energy:
# 3. Loudness:
# 4. Tempo:
# 5. Valence:
# 6. Acousticness:
# 7. Instrumentalness:
# 8. Liveness:
# 9. Speechiness:

# %% [markdown]
# **Neural Network Permutation Importance** for each feature (classification):
#
# 1. Danceability:
# 2. Energy:
# 3. Loudness:
# 4. Tempo:
# 5. Valence:
# 6. Acousticness:
# 7. Instrumentalness:
# 8. Liveness:
# 9. Speechiness:

# %% [markdown]
# **Dataset 2:**

# %% [markdown]
# **CNN Train Loss and Train Accuracy:**

# %% [markdown]
# **CNN Test Loss and Test Accuracy:**

# %% [markdown]
# **CNN Test Accuracy:**

# %% [markdown]
# **CNN Confusion Matrix:**

# %%
'''
# confusion matrix code

from sklearn.metrics import confusion_matrix
import seaborn as sns

# genre labels
class_names = ['blues',  'classical',  'country',  'disco',  'hiphop',  'jazz',  'metal',  'pop',  'reggae', 'rock']

all_preds = []
all_labels = []

model.eval()

with torch.no_grad():

    for xb, yb in test_loader:

        xb = xb.to(device)

        preds = model(xb).argmax(dim=1).cpu().numpy()

        all_preds.extend(preds)
        all_labels.extend(yb.numpy())

cm = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt = 'd', cmap = 'Blues', xticklabels = class_names, yticklabels = class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
'''
